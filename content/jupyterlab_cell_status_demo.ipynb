# %% [markdown]
# # Cell Status Indicator
#
# This extension provides an color themed cell status indicator that indicates the run status of a cell.
#
# Indications include:
#
# - cell queued for execution or executing;
# - cell executed successfully;
# - cell executed unsuccessfully.
#
# ![image.png](attachment:d744666c-01a4-4283-9a29-5f25272e87fb.png)
#
# Based on the classic notebook[`innovationOUtside/nb_cell_execution_status`](https://github.com/innovationOUtside/nb_cell_execution_status) extension, which in turn was originally inspired by the [`NII-cloud-operation/Jupyter-multi_outputs`](https://github.com/NII-cloud-operation/Jupyter-multi_outputs) classic notebook extension.

# %%
print("success")
# Out:
# success

# %%
error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 error
#
# NameError: name 'error' is not defined

# %%
import time
time.sleep(10)
